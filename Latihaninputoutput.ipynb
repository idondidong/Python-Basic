# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('contoh.csv')

# %%
df
# Out:
#    nik   nama    asal pekerjaan
# 0   11   arip  jember      guru
# 1   22  anggi     bwi  pedagang
# 2   33   andi  jember      guru
# 3   44    abi     bwi    satpam
# 4   55   awuk     bws      guru

# %%
df.to_csv('hasil eksport.csv', index=False)

# %%
df = pd.read_excel('contoh lagi.xlsx', index_col=0)

# %%
df
# Out:
#    nik   nama    asal pekerjaan
# 0   11   arip  jember      guru
# 1   22  anggi     bwi  pedagang
# 2   33   andi  jember      guru
# 3   44    abi     bwi    satpam
# 4   55   awuk     bws      guru

# %%
df = pd.read_html('https://archive.ics.uci.edu/ml/datasets.php')
df
# Out:
# [                                                   0  \
#  0  Center for Machine Learning and Intelligent Sy...
#
#                                                     1
#  0  About Citation Policy Donate a Data Set Contac...  ,
#                                                     0  \
#  0  Browse Through:  Default Task Classification (...
#
#                                                     1
#  0  557 Data Sets  Table View List View  Name  Dat...  ,
#                   0
#  0  Browse Through:,
#                                                      0
#  0                                        Default Task
#  1   Classification (417)Regression (129)Clustering...
#  2                                      Attribute Type
#  3           Categorical (38)Numerical (375)Mixed (55)
#  4                                           Data Type
#  5   Multivariate (434)Univariate (27)Sequential (5...
#  6                                                Area
# ...

# %%
type(df)
# Out:
# list

# %%
df[0]
# Out:
#                                                    0  \
# 0  Center for Machine Learning and Intelligent Sy...
#
#                                                    1
# 0  About Citation Policy Donate a Data Set Contac...
